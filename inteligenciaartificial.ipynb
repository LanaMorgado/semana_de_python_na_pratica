# %%
# %pip install opencv-python
# %pip install mediapipe
# %pip install cvzone
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\lanam\appdata\local\programs\python\python311\lib\site-packages (from opencv-python) (1.26.4)
# Downloading opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl (38.8 MB)
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ------- -------------------------------- 7.1/38.8 MB 36.4 MB/s eta 0:00:01
#    -------------- ------------------------- 14.2/38.8 MB 35.6 MB/s eta 0:00:01
#    ---------------------- ----------------- 22.3/38.8 MB 36.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 29.1/38.8 MB 34.8 MB/s eta 0:00:01
#    ------------------------------------ --- 35.4/38.8 MB 35.1 MB/s eta 0:00:01
#    ---------------------------------------  38.8/38.8 MB 32.9 MB/s eta 0:00:01
#    ---------------------------------------- 38.8/38.8 MB 29.1 MB/s eta 0:00:00
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.10.0.84
# Note: you may need to restart the kernel to use updated packages.
# Collecting mediapipe
#   Downloading mediapipe-0.10.14-cp311-cp311-win_amd64.whl.metadata (9.9 kB)
# Collecting absl-py (from mediapipe)
#   Downloading absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\lanam\appdata\local\programs\python\python311\lib\site-packages (from mediapipe) (23.2.0)
# Collecting flatbuffers>=2.0 (from mediapipe)
#   Downloading flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting jax (from mediapipe)
#   Downloading jax-0.4.31-py3-none-any.whl.metadata (22 kB)
# Collecting jaxlib (from mediapipe)
#   Downloading jaxlib-0.4.31-cp311-cp311-win_amd64.whl.metadata (1.0 kB)
# Requirement already satisfied: matplotlib in c:\users\lanam\appdata\local\programs\python\python311\lib\site-packages (from mediapipe) (3.8.4)
# Requirement already satisfied: numpy in c:\users\lanam\appdata\local\programs\python\python311\lib\site-packages (from mediapipe) (1.26.4)
# Collecting opencv-contrib-python (from mediapipe)
#   Downloading opencv_contrib_python-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: protobuf<5,>=4.25.3 in c:\users\lanam\appdata\local\programs\python\python311\lib\site-packages (from mediapipe) (4.25.3)
# Collecting sounddevice>=0.4.4 (from mediapipe)
#   Downloading sounddevice-0.5.0-py3-none-win_amd64.whl.metadata (1.4 kB)
# Collecting CFFI>=1.0 (from sounddevice>=0.4.4->mediapipe)
#   Downloading cffi-1.17.0-cp311-cp311-win_amd64.whl.metadata (1.6 kB)
# Collecting ml-dtypes>=0.2.0 (from jax->mediapipe)
#   Downloading ml_dtypes-0.4.0-cp311-cp311-win_amd64.whl.metadata (20 kB)
# Collecting opt-einsum (from jax->mediapipe)
#   Downloading opt_einsum-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: scipy>=1.10 in c:\users\lanam\appdata\local\programs\python\python311\lib\site-packages (from jax->mediapipe) (1.13.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lanam\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->mediapipe) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\lanam\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lanam\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->mediapipe) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\lanam\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->mediapipe) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\lanam\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->mediapipe) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\lanam\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->mediapipe) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\lanam\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->mediapipe) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lanam\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Collecting pycparser (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe)
#   Downloading pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Requirement already satisfied: six>=1.5 in c:\users\lanam\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# Downloading mediapipe-0.10.14-cp311-cp311-win_amd64.whl (50.8 MB)
#    ---------------------------------------- 0.0/50.8 MB ? eta -:--:--
#    ----- ---------------------------------- 7.6/50.8 MB 39.3 MB/s eta 0:00:02
#    ----------- ---------------------------- 15.2/50.8 MB 38.3 MB/s eta 0:00:01
#    ----------------- ---------------------- 22.5/50.8 MB 37.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 30.1/50.8 MB 36.8 MB/s eta 0:00:01
#    ------------------------------ --------- 38.5/50.8 MB 37.7 MB/s eta 0:00:01
#    ------------------------------------ --- 45.9/50.8 MB 37.4 MB/s eta 0:00:01
#    ---------------------------------------  50.6/50.8 MB 37.5 MB/s eta 0:00:01
#    ---------------------------------------- 50.8/50.8 MB 34.1 MB/s eta 0:00:00
# Downloading flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Downloading sounddevice-0.5.0-py3-none-win_amd64.whl (189 kB)
# Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
# Downloading jax-0.4.31-py3-none-any.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 28.7 MB/s eta 0:00:00
# Downloading jaxlib-0.4.31-cp311-cp311-win_amd64.whl (56.3 MB)
#    ---------------------------------------- 0.0/56.3 MB ? eta -:--:--
#    ----- ---------------------------------- 7.3/56.3 MB 34.9 MB/s eta 0:00:02
#    ---------- ----------------------------- 14.9/56.3 MB 36.2 MB/s eta 0:00:02
#    -------------- ------------------------- 19.9/56.3 MB 32.3 MB/s eta 0:00:02
#    ------------------ --------------------- 26.0/56.3 MB 31.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 32.5/56.3 MB 31.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 40.4/56.3 MB 32.5 MB/s eta 0:00:01
#    --------------------------------- ------ 47.2/56.3 MB 32.7 MB/s eta 0:00:01
#    -------------------------------------- - 54.5/56.3 MB 32.8 MB/s eta 0:00:01
#    ---------------------------------------- 56.3/56.3 MB 30.4 MB/s eta 0:00:00
# Downloading opencv_contrib_python-4.10.0.84-cp37-abi3-win_amd64.whl (45.5 MB)
#    ---------------------------------------- 0.0/45.5 MB ? eta -:--:--
#    ------ --------------------------------- 7.1/45.5 MB 33.6 MB/s eta 0:00:02
#    ------------ --------------------------- 14.4/45.5 MB 34.9 MB/s eta 0:00:01
#    ------------------- -------------------- 21.8/45.5 MB 35.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 26.7/45.5 MB 32.0 MB/s eta 0:00:01
#    -------------------------- ------------- 30.1/45.5 MB 29.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 33.0/45.5 MB 26.2 MB/s eta 0:00:01
#    --------------------------------- ------ 38.5/45.5 MB 26.3 MB/s eta 0:00:01
#    ------------------------------------- -- 42.5/45.5 MB 25.2 MB/s eta 0:00:01
#    ---------------------------------------  45.1/45.5 MB 23.9 MB/s eta 0:00:01
#    ---------------------------------------- 45.5/45.5 MB 21.8 MB/s eta 0:00:00
# Downloading cffi-1.17.0-cp311-cp311-win_amd64.whl (180 kB)
# Downloading ml_dtypes-0.4.0-cp311-cp311-win_amd64.whl (126 kB)
# Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Downloading pycparser-2.22-py3-none-any.whl (117 kB)
# Installing collected packages: flatbuffers, pycparser, opt-einsum, opencv-contrib-python, ml-dtypes, absl-py, jaxlib, CFFI, sounddevice, jax, mediapipe
# Successfully installed CFFI-1.17.0 absl-py-2.1.0 flatbuffers-24.3.25 jax-0.4.31 jaxlib-0.4.31 mediapipe-0.10.14 ml-dtypes-0.4.0 opencv-contrib-python-4.10.0.84 opt-einsum-3.3.0 pycparser-2.22 sounddevice-0.5.0
# Note: you may need to restart the kernel to use updated packages.
# Collecting cvzone
#   Downloading cvzone-1.6.1.tar.gz (25 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: opencv-python in c:\users\lanam\appdata\local\programs\python\python311\lib\site-packages (from cvzone) (4.10.0.84)
# Requirement already satisfied: numpy in c:\users\lanam\appdata\local\programs\python\python311\lib\site-packages (from cvzone) (1.26.4)
# Building wheels for collected packages: cvzone
#   Building wheel for cvzone (pyproject.toml): started
#   Building wheel for cvzone (pyproject.toml): finished with status 'done'
#   Created wheel for cvzone: filename=cvzone-1.6.1-py3-none-any.whl size=26310 sha256=0add02f728ea1b4772bf3dbc6e8a6e42b52a9693b52fb1412a82446c5df5647f
#   Stored in directory: c:\users\lanam\appdata\local\pip\cache\wheels\ab\36\ec\47be2d4e59dc4289e684d5b0dde54d1e72e51a614e57690e85
# Successfully built cvzone
# Installing collected packages: cvzone
# Successfully installed cvzone-1.6.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
from cvzone.HandTrackingModule import HandDetector

# Inicializa a webcam
webcam = cv2.VideoCapture(0)

# Inicializa o rastreador de mãos
rastreador = HandDetector(detectionCon=0.8, maxHands=2)

while True:
    # Captura a imagem da webcam
    sucesso, imagem = webcam.read()

    # Detecta as mãos no quadro
    hands, imagem_maos = rastreador.findHands(imagem)

    # Mostra o quadro com as marcações
    cv2.imshow("Projeto 4 - IA", imagem_maos)

    # Encerra a aplicação quando qualquer tecla é pressionada
    if cv2.waitKey(1) != -1:
        break

# Libera a câmera e fecha as janelas
webcam.release()
cv2.destroyAllWindows()

# %%
# Exemplo de loop com while
contador = 5
while contador > 0:
    print(contador)
    contador = contador - 1

# Exemplo de condicional com if
linguagem = "Python"
if linguagem == "Python":
    print("Melhor linguagem do mundo!")

# Exemplo de loop infinito com while e if
while True:
    texto = input("Digite algo: ")
    print(texto)
    if texto == "parar":
        break
# Out:
# 5
# 4
# 3
# 2
# 1
# Melhor linguagem do mundo!
# python
# k
# escape
# Escape
#
# parar
